# %%
import pandas as pd

# %%
import pandas as pd 

mydataset={
    'cars':["bmw","audi","rangerover"],
    'quantity':["2",2,1]
}



print(pd.DataFrame(mydataset))

# %%
a = [1, "5", 2]

myvar = pd.Series(a)

print(myvar)

# %%
import pandas as pd

a = [1, 7, 2,5]
b=len(a)

myvar = pd.Series(a, index = [chr(x) for x in range(65,65+b)])

print(myvar)

# %%
print(myvar["D"])

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}
b=len(calories)


myvar = pd.Series(calories)
print(myvar)

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar.loc[["day1","day3"]])

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}


df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)

# %%
hotels=pd.read_csv('indian_food.csv')

# %%
print(hotels.head(10))

# %%
print(pd.options.display.max_rows)

# %%
print(hotels.to_string())

# %%
pd.options.display.max_rows = 119389
hotels=pd.read_csv('indian_food.csv')
print(hotels)

# %%
carsjson= pd.read_json('cars.json')

print(carsjson)

# %%
print(carsjson.to_string())

# %%
print(carsjson.info())

# %%
#loading datset from hugging face
from datasets import load_dataset

df= load_dataset('lukebarousse/data_jobs')
import pandas as pd

df_pandas = df['train'].to_pandas()
df_pandas.head()

# %%
df_pandas

# %%
df_pandas[['job_title_short']]

# %%
df_pandas.iloc[90]

# %%
df_pandas.iloc[90:100]

# %%
df_pandas.iloc[90:100, 0:2]

# %%
df_pandas.info()

# %%
df_pandas[df_pandas.job_title_short=="Data Analyst"]

# %%
now=df_pandas[(df_pandas.job_title_short=="Data Analyst") & (df_pandas.salary_year_avg > 10000)]
now

# %%
now[['job_title_short','salary_year_avg']]

# %%
now=df_pandas[(df_pandas.job_title_short=="Data Analyst") & (df_pandas.salary_year_avg.notna())]
now

# %%
df_pandas.info()

# %%
df_pandas['job_posted_date'].dtype
# Out:
# <StringDtype(na_value=nan)>

# %%
pd.to_datetime(df_pandas.job_posted_date)
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# 785740   2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: datetime64[us]

# %%
df_pandas['job_posted_date']= pd.to_datetime(df_pandas.job_posted_date)

# %%
df_pandas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  str
#  1   job_title              785740 non-null  str
#  2   job_location           784696 non-null  str
#  3   job_via                785733 non-null  str
#  4   job_schedule_type      773074 non-null  str
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  str
#  7   job_posted_date        785741 non-null  datetime64[us]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  str
#  11  salary_rate            33067 non-null   str
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  str
# ...

# %%
df_pandas.drop(labels='salary_hour_avg',axis=1,inplace=True)

# %%
df_pandas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  str
#  1   job_title              785740 non-null  str
#  2   job_location           784696 non-null  str
#  3   job_via                785733 non-null  str
#  4   job_schedule_type      773074 non-null  str
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  str
#  7   job_posted_date        785741 non-null  datetime64[us]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  str
#  11  salary_rate            33067 non-null   str
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  str
#  14  job_skills             668704 non-null  str
# ...
